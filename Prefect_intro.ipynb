# %% [markdown]
# # Introduction to Orchestation and Sequencing of Workflows with Python
# Workflow orchestations refers to the process of defining, coordinating and automating the execution of multiple computational tasks that together form a larger process. Instead of running scripts independtly, orchestation structure these processes as pipelines, where each task is executed in a specific arder and may depend on the output of previous tasks.
#
# In modern data processing systems, machine learning workflows, and infrastructure automation, processes are commonly divided into stages such as data acquisition, transformation, analysis, storage, and reporting. Workflow orchestration allows these stages to be modeled as a structured flow of tasks, enabling controlled execution and management of events such as failures, retries, and scheduled runs.
#
# We can think of workflows as Directed Acylic graphs (DAG). Each node represents a task and the edges represent the dependence between them. This kind of structure allow us to clearly define which tastks we must run sequentially, and which ones in parallel.
#
# In the Python ecosystem, there are several frameworks that have been developed specifically for workflow orchestation, for example, Prefect and Apache Airflow. We can define the tasks, the dependencies, the schedule execution and monitor the behavior of complete pipelines.
#
# The author is almost new in programming orchestation, so this repository is his way to document the process of learning. Writting commands, libraries, etc.
#
# The principal source for this repository is the oficial documentation of Prefect, since this is a powerful motor that can work just with Python: https://docs.prefect.io/v3/get-started

# %% [markdown]
# ## Installing Prefect
# Published as a Python library, Prefect requires Python ver 3.10 (or newer).
#
# To install Prefect run this code:

# %%
pip install -U prefect
# Out:
# Collecting prefectNote: you may need to restart the kernel to use updated packages.
#
#   Downloading prefect-3.6.22-py3-none-any.whl.metadata (13 kB)
# Collecting aiosqlite<1.0.0,>=0.17.0 (from prefect)
#   Downloading aiosqlite-0.22.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting alembic<2.0.0,>=1.7.5 (from prefect)
#   Downloading alembic-1.18.4-py3-none-any.whl.metadata (7.2 kB)
# Collecting amplitude-analytics<2.0.0,>=1.2.1 (from prefect)
#   Downloading amplitude_analytics-1.2.2-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.4.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (4.7.0)
# Collecting apprise<2.0.0,>=1.1.0 (from prefect)
#   Downloading apprise-1.9.8-py3-none-any.whl.metadata (56 kB)
# Collecting asgi-lifespan<3.0,>=1.0 (from prefect)
#   Downloading asgi_lifespan-2.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting asyncpg<1.0.0,>=0.23 (from prefect)
#   Downloading asyncpg-0.31.0-cp313-cp313-win_amd64.whl.metadata (4.5 kB)
# Requirement already satisfied: cachetools<8.0,>=5.3 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (5.5.1)
# Requirement already satisfied: click<9,>=8.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (8.1.8)
# Requirement already satisfied: cloudpickle<4.0,>=2.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (3.0.0)
# Collecting coolname<5.0.0,>=1.0.4 (from prefect)
#   Downloading coolname-4.0.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: cryptography>=36.0.1 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (44.0.1)
# Collecting cyclopts>=4.8.0 (from prefect)
#   Downloading cyclopts-4.10.0-py3-none-any.whl.metadata (12 kB)
# Collecting dateparser<2.0.0,>=1.1.1 (from prefect)
#   Downloading dateparser-1.3.0-py3-none-any.whl.metadata (30 kB)
# Collecting docker<8.0,>=4.0 (from prefect)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting exceptiongroup>=1.0.0 (from prefect)
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting fastapi<1.0.0,>=0.111.0 (from prefect)
#   Downloading fastapi-0.135.1-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: fsspec>=2022.5.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (2025.3.2)
# Collecting graphviz>=0.20.1 (from prefect)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Collecting griffe<3.0.0,>=0.49.0 (from prefect)
#   Downloading griffe-2.0.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: httpcore<2.0.0,>=1.0.5 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (1.0.9)
# Requirement already satisfied: httpx!=0.23.2,>=0.23 in c:\users\ian\anaconda3\lib\site-packages (from httpx[http2]!=0.23.2,>=0.23->prefect) (0.28.1)
# Collecting humanize<5.0.0,>=4.9.0 (from prefect)
#   Downloading humanize-4.15.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting jinja2-humanize-extension>=0.4.0 (from prefect)
#   Downloading jinja2_humanize_extension-0.4.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.6 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (3.1.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.32 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (1.33)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (4.23.0)
# Collecting opentelemetry-api<2.0.0,>=1.27.0 (from prefect)
#   Downloading opentelemetry_api-1.40.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting orjson<4.0,>=3.7 (from prefect)
#   Downloading orjson-3.11.7-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: packaging<26.1,>=21.3 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (24.2)
# Requirement already satisfied: pathspec>=0.8.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (0.10.3)
# Collecting pluggy>=1.6.0 (from prefect)
#   Downloading pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: prometheus-client>=0.20.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (0.21.1)
# Requirement already satisfied: pydantic!=2.11.0,!=2.11.1,!=2.11.2,!=2.11.3,!=2.11.4,<3.0.0,>=2.10.1 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (2.10.3)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.12.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (2.27.1)
# Collecting pydantic-extra-types<3.0.0,>=2.8.2 (from prefect)
#   Downloading pydantic_extra_types-2.11.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: pydantic-settings!=2.9.0,<3.0.0,>2.2.1 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (2.6.1)
# Collecting pydocket>=0.17.7 (from prefect)
#   Downloading pydocket-0.18.2-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (2.9.0.post0)
# Requirement already satisfied: python-slugify<9.0,>=5.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (5.0.2)
# Requirement already satisfied: pytz<2027,>=2021.1 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (2024.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.4.1 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (6.0.2)
# Requirement already satisfied: readchar<5.0.0,>=4.0.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (4.0.5)
# Requirement already satisfied: rfc3339-validator<0.2.0,>=0.1.4 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (0.1.4)
# Requirement already satisfied: rich<15.0,>=11.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (13.9.4)
# Requirement already satisfied: ruamel-yaml-clib>=0.2.8 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (0.2.12)
# Requirement already satisfied: ruamel-yaml>=0.17.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (0.18.10)
# Collecting semver>=3.0.4 (from prefect)
#   Downloading semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: sniffio<2.0.0,>=1.3.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (1.3.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in c:\users\ian\anaconda3\lib\site-packages (from sqlalchemy[asyncio]<3.0.0,>=2.0->prefect) (2.0.39)
# Requirement already satisfied: toml>=0.10.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (0.10.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.10.0 in c:\users\ian\anaconda3\lib\site-packages (from prefect) (4.12.2)
# Collecting uvicorn!=0.29.0,>=0.14.0 (from prefect)
#   Downloading uvicorn-0.41.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting websockets<17.0,>=15.0.1 (from prefect)
#   Downloading websockets-16.0-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Collecting whenever<0.10.0,>=0.7.3 (from prefect)
#   Downloading whenever-0.9.5-cp313-cp313-win_amd64.whl.metadata (12 kB)
# Collecting Mako (from alembic<2.0.0,>=1.7.5->prefect)
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: idna>=2.8 in c:\users\ian\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.4.0->prefect) (3.7)
# Requirement already satisfied: requests in c:\users\ian\anaconda3\lib\site-packages (from apprise<2.0.0,>=1.1.0->prefect) (2.32.3)
# Collecting requests-oauthlib (from apprise<2.0.0,>=1.1.0->prefect)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: markdown in c:\users\ian\anaconda3\lib\site-packages (from apprise<2.0.0,>=1.1.0->prefect) (3.8)
# Requirement already satisfied: certifi in c:\users\ian\anaconda3\lib\site-packages (from apprise<2.0.0,>=1.1.0->prefect) (2026.1.4)
# Requirement already satisfied: tzdata in c:\users\ian\anaconda3\lib\site-packages (from apprise<2.0.0,>=1.1.0->prefect) (2025.2)
# Requirement already satisfied: colorama in c:\users\ian\anaconda3\lib\site-packages (from click<9,>=8.0->prefect) (0.4.6)
# Collecting pytz<2027,>=2021.1 (from prefect)
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: regex>=2024.9.11 in c:\users\ian\anaconda3\lib\site-packages (from dateparser<2.0.0,>=1.1.1->prefect) (2024.11.6)
# Collecting tzlocal>=0.2 (from dateparser<2.0.0,>=1.1.1->prefect)
#   Downloading tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: pywin32>=304 in c:\users\ian\anaconda3\lib\site-packages (from docker<8.0,>=4.0->prefect) (308)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\ian\anaconda3\lib\site-packages (from docker<8.0,>=4.0->prefect) (2.3.0)
# Collecting starlette>=0.46.0 (from fastapi<1.0.0,>=0.111.0->prefect)
#   Downloading starlette-0.52.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting typing-inspection>=0.4.2 (from fastapi<1.0.0,>=0.111.0->prefect)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0.0,>=0.111.0->prefect)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting griffecli==2.0.0 (from griffe<3.0.0,>=0.49.0->prefect)
#   Downloading griffecli-2.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting griffelib==2.0.0 (from griffe<3.0.0,>=0.49.0->prefect)
#   Downloading griffelib-2.0.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: h11>=0.16 in c:\users\ian\anaconda3\lib\site-packages (from httpcore<2.0.0,>=1.0.5->prefect) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ian\anaconda3\lib\site-packages (from jinja2<4.0.0,>=3.1.6->prefect) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ian\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.32->prefect) (2.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ian\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ian\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ian\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ian\anaconda3\lib\site-packages (from jsonschema<5.0.0,>=4.18.0->prefect) (0.22.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\ian\anaconda3\lib\site-packages (from opentelemetry-api<2.0.0,>=1.27.0->prefect) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\ian\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.27.0->prefect) (3.21.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ian\anaconda3\lib\site-packages (from pydantic!=2.11.0,!=2.11.1,!=2.11.2,!=2.11.3,!=2.11.4,<3.0.0,>=2.10.1->prefect) (0.6.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ian\anaconda3\lib\site-packages (from pydantic-settings!=2.9.0,<3.0.0,>2.2.1->prefect) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\ian\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->prefect) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\ian\anaconda3\lib\site-packages (from python-slugify<9.0,>=5.0->prefect) (1.3)
# Requirement already satisfied: setuptools>=41.0 in c:\users\ian\anaconda3\lib\site-packages (from readchar<5.0.0,>=4.0.0->prefect) (72.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ian\anaconda3\lib\site-packages (from rich<15.0,>=11.0->prefect) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ian\anaconda3\lib\site-packages (from rich<15.0,>=11.0->prefect) (2.19.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ian\anaconda3\lib\site-packages (from sqlalchemy<3.0.0,>=2.0->sqlalchemy[asyncio]<3.0.0,>=2.0->prefect) (3.1.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\ian\anaconda3\lib\site-packages (from cryptography>=36.0.1->prefect) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\ian\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.1->prefect) (2.21)
# Collecting docstring-parser<4.0,>=0.15 (from cyclopts>=4.8.0->prefect)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting rich-rst<2.0.0,>=1.3.1 (from cyclopts>=4.8.0->prefect)
#   Downloading rich_rst-1.3.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: docutils in c:\users\ian\anaconda3\lib\site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=4.8.0->prefect) (0.21.2)
# Collecting h2<5,>=3 (from httpx[http2]!=0.23.2,>=0.23->prefect)
#   Downloading h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect)
#   Downloading hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect)
#   Downloading hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ian\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<15.0,>=11.0->prefect) (0.1.0)
# Collecting cloudpickle<4.0,>=2.0 (from prefect)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting cronsim>=2.6 (from pydocket>=0.17.7->prefect)
#   Downloading cronsim-2.7-py3-none-any.whl.metadata (6.9 kB)
# Collecting fakeredis>=2.32.1 (from fakeredis[lua]>=2.32.1->pydocket>=0.17.7->prefect)
#   Downloading fakeredis-2.34.1-py3-none-any.whl.metadata (4.4 kB)
# Collecting py-key-value-aio>=0.3.0 (from py-key-value-aio[memory,redis]>=0.3.0->pydocket>=0.17.7->prefect)
#   Downloading py_key_value_aio-0.4.4-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-json-logger>=2.0.7 in c:\users\ian\anaconda3\lib\site-packages (from pydocket>=0.17.7->prefect) (3.2.1)
# Collecting redis>=5 (from pydocket>=0.17.7->prefect)
#   Downloading redis-7.3.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: typer>=0.15.1 in c:\users\ian\anaconda3\lib\site-packages (from pydocket>=0.17.7->prefect) (0.20.0)
# Collecting uncalled-for>=0.2.0 (from pydocket>=0.17.7->prefect)
#   Downloading uncalled_for-0.2.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: sortedcontainers>=2 in c:\users\ian\anaconda3\lib\site-packages (from fakeredis>=2.32.1->fakeredis[lua]>=2.32.1->pydocket>=0.17.7->prefect) (2.4.0)
# Collecting lupa>=2.1 (from fakeredis[lua]>=2.32.1->pydocket>=0.17.7->prefect)
#   Downloading lupa-2.6-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting beartype>=0.20.0 (from py-key-value-aio>=0.3.0->py-key-value-aio[memory,redis]>=0.3.0->pydocket>=0.17.7->prefect)
#   Downloading beartype-0.22.9-py3-none-any.whl.metadata (37 kB)
# Collecting typing-extensions<5.0.0,>=4.10.0 (from prefect)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ian\anaconda3\lib\site-packages (from requests->apprise<2.0.0,>=1.1.0->prefect) (3.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ian\anaconda3\lib\site-packages (from typer>=0.15.1->pydocket>=0.17.7->prefect) (1.5.0)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->apprise<2.0.0,>=1.1.0->prefect)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Downloading prefect-3.6.22-py3-none-any.whl (12.0 MB)
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.0 MB 6.1 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/12.0 MB 6.6 MB/s eta 0:00:02
#    ------------- -------------------------- 3.9/12.0 MB 6.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.2/12.0 MB 6.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.8/12.0 MB 6.7 MB/s eta 0:00:01
#    --------------------------- ------------ 8.4/12.0 MB 6.8 MB/s eta 0:00:01
#    -------------------------------- ------- 9.7/12.0 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------- -- 11.3/12.0 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 6.5 MB/s eta 0:00:00
# Downloading aiosqlite-0.22.1-py3-none-any.whl (17 kB)
# Downloading alembic-1.18.4-py3-none-any.whl (263 kB)
# Downloading amplitude_analytics-1.2.2-py3-none-any.whl (24 kB)
# Downloading apprise-1.9.8-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------- ----- 1.3/1.5 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 6.3 MB/s eta 0:00:00
# Downloading asgi_lifespan-2.1.0-py3-none-any.whl (10 kB)
# Downloading asyncpg-0.31.0-cp313-cp313-win_amd64.whl (596 kB)
#    ---------------------------------------- 0.0/596.6 kB ? eta -:--:--
#    ---------------------------------------- 596.6/596.6 kB 3.9 MB/s eta 0:00:00
# Downloading coolname-4.0.0-py3-none-any.whl (39 kB)
# Downloading dateparser-1.3.0-py3-none-any.whl (318 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.135.1-py3-none-any.whl (116 kB)
# Downloading griffe-2.0.0-py3-none-any.whl (5.2 kB)
# Downloading griffecli-2.0.0-py3-none-any.whl (9.3 kB)
# Downloading griffelib-2.0.0-py3-none-any.whl (142 kB)
# Downloading humanize-4.15.0-py3-none-any.whl (132 kB)
# Downloading opentelemetry_api-1.40.0-py3-none-any.whl (68 kB)
# Downloading orjson-3.11.7-cp313-cp313-win_amd64.whl (124 kB)
# Downloading pydantic_extra_types-2.11.0-py3-none-any.whl (74 kB)
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Downloading websockets-16.0-cp313-cp313-win_amd64.whl (178 kB)
# Downloading whenever-0.9.5-cp313-cp313-win_amd64.whl (440 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading cyclopts-4.10.0-py3-none-any.whl (204 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading rich_rst-1.3.2-py3-none-any.whl (12 kB)
# Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading h2-4.3.0-py3-none-any.whl (61 kB)
# Downloading hpack-4.1.0-py3-none-any.whl (34 kB)
# Downloading hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading jinja2_humanize_extension-0.4.0-py3-none-any.whl (4.8 kB)
# Downloading pluggy-1.6.0-py3-none-any.whl (20 kB)
# Downloading pydocket-0.18.2-py3-none-any.whl (99 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading cronsim-2.7-py3-none-any.whl (14 kB)
# Downloading fakeredis-2.34.1-py3-none-any.whl (122 kB)
# Downloading lupa-2.6-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------- -------- 1.3/1.7 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 6.2 MB/s eta 0:00:00
# Downloading py_key_value_aio-0.4.4-py3-none-any.whl (152 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading beartype-0.22.9-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------  1.3/1.3 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 6.0 MB/s eta 0:00:00
# Downloading redis-7.3.0-py3-none-any.whl (404 kB)
# Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Downloading uncalled_for-0.2.0-py3-none-any.whl (11 kB)
# Downloading uvicorn-0.41.0-py3-none-any.whl (68 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: pytz, lupa, websockets, uncalled-for, tzlocal, typing-extensions, semver, redis, pluggy, orjson, oauthlib, Mako, hyperframe, humanize, hpack, griffelib, graphviz, exceptiongroup, docstring-parser, cronsim, coolname, cloudpickle, beartype, asyncpg, asgi-lifespan, annotated-doc, amplitude-analytics, aiosqlite, whenever, uvicorn, typing-inspection, starlette, requests-oauthlib, py-key-value-aio, opentelemetry-api, jinja2-humanize-extension, h2, griffecli, fakeredis, docker, dateparser, rich-rst, griffe, apprise, alembic, pydocket, pydantic-extra-types, fastapi, cyclopts, prefect
#
#   Attempting uninstall: pytz
#
#     Found existing installation: pytz 2024.1
#
#    ----------------------------------------  0/50 [pytz]
#     Uninstalling pytz-2024.1:
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#       Successfully uninstalled pytz-2024.1
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#    ----------------------------------------  0/50 [pytz]
#     ---------------------------------------  1/50 [lupa]
#    - --------------------------------------  2/50 [websockets]
#    - --------------------------------------  2/50 [websockets]
#    - --------------------------------------  2/50 [websockets]
#    - --------------------------------------  2/50 [websockets]
#    - --------------------------------------  2/50 [websockets]
#    -- -------------------------------------  3/50 [uncalled-for]
#   Attempting uninstall: typing-extensions
#    -- -------------------------------------  3/50 [uncalled-for]
#    ---- -----------------------------------  5/50 [typing-extensions]
#     Found existing installation: typing_extensions 4.12.2
#    ---- -----------------------------------  5/50 [typing-extensions]
#     Uninstalling typing_extensions-4.12.2:
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  5/50 [typing-extensions]
#   Attempting uninstall: semver
#    ---- -----------------------------------  5/50 [typing-extensions]
#     Found existing installation: semver 3.0.2
#    ---- -----------------------------------  5/50 [typing-extensions]
#     Uninstalling semver-3.0.2:
#    ---- -----------------------------------  5/50 [typing-extensions]
#       Successfully uninstalled semver-3.0.2
#    ---- -----------------------------------  5/50 [typing-extensions]
#    ---- -----------------------------------  6/50 [semver]
#    ----- ----------------------------------  7/50 [redis]
#    ----- ----------------------------------  7/50 [redis]
#    ----- ----------------------------------  7/50 [redis]
#    ----- ----------------------------------  7/50 [redis]
#    ----- ----------------------------------  7/50 [redis]
#    ----- ----------------------------------  7/50 [redis]
#    ----- ----------------------------------  7/50 [redis]
#    ----- ----------------------------------  7/50 [redis]
#    ----- ----------------------------------  7/50 [redis]
#    ----- ----------------------------------  7/50 [redis]
#    ----- ----------------------------------  7/50 [redis]
#    ----- ----------------------------------  7/50 [redis]
#    ----- ----------------------------------  7/50 [redis]
#    ----- ----------------------------------  7/50 [redis]
#   Attempting uninstall: pluggy
#    ----- ----------------------------------  7/50 [redis]
#    ------ ---------------------------------  8/50 [pluggy]
#     Found existing installation: pluggy 1.5.0
#    ------ ---------------------------------  8/50 [pluggy]
#     Uninstalling pluggy-1.5.0:
#    ------ ---------------------------------  8/50 [pluggy]
#       Successfully uninstalled pluggy-1.5.0
#    ------ ---------------------------------  8/50 [pluggy]
#    ------ ---------------------------------  8/50 [pluggy]
#    ------- --------------------------------  9/50 [orjson]
#    -------- ------------------------------- 10/50 [oauthlib]
#    -------- ------------------------------- 10/50 [oauthlib]
#    -------- ------------------------------- 10/50 [oauthlib]
#    -------- ------------------------------- 10/50 [oauthlib]
#    -------- ------------------------------- 10/50 [oauthlib]
#    -------- ------------------------------- 10/50 [oauthlib]
#    -------- ------------------------------- 11/50 [Mako]
#    -------- ------------------------------- 11/50 [Mako]
#    -------- ------------------------------- 11/50 [Mako]
#    -------- ------------------------------- 11/50 [Mako]
#    --------- ------------------------------ 12/50 [hyperframe]
#    ---------- ----------------------------- 13/50 [humanize]
#    ---------- ----------------------------- 13/50 [humanize]
#    ---------- ----------------------------- 13/50 [humanize]
#    ----------- ---------------------------- 14/50 [hpack]
#    ------------ --------------------------- 15/50 [griffelib]
#    ------------ --------------------------- 15/50 [griffelib]
#    ------------ --------------------------- 15/50 [griffelib]
#    ------------ --------------------------- 15/50 [griffelib]
#    ------------ --------------------------- 15/50 [griffelib]
#    ------------ --------------------------- 15/50 [griffelib]
#    ------------ --------------------------- 16/50 [graphviz]
#    ------------ --------------------------- 16/50 [graphviz]
#    ------------ --------------------------- 16/50 [graphviz]
#    -------------- ------------------------- 18/50 [docstring-parser]
#    -------------- ------------------------- 18/50 [docstring-parser]
#    --------------- ------------------------ 19/50 [cronsim]
#    ---------------- ----------------------- 20/50 [coolname]
#    ---------------- ----------------------- 20/50 [coolname]
#   Attempting uninstall: cloudpickle
#    ---------------- ----------------------- 20/50 [coolname]
#     Found existing installation: cloudpickle 3.0.0
#    ---------------- ----------------------- 20/50 [coolname]
#     Uninstalling cloudpickle-3.0.0:
#    ---------------- ----------------------- 20/50 [coolname]
#       Successfully uninstalled cloudpickle-3.0.0
#    ---------------- ----------------------- 20/50 [coolname]
#    ---------------- ----------------------- 21/50 [cloudpickle]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ----------------- ---------------------- 22/50 [beartype]
#    ------------------ --------------------- 23/50 [asyncpg]
#    ------------------ --------------------- 23/50 [asyncpg]
#    ------------------ --------------------- 23/50 [asyncpg]
#    ------------------- -------------------- 24/50 [asgi-lifespan]
#    -------------------- ------------------- 26/50 [amplitude-analytics]
#    --------------------- ------------------ 27/50 [aiosqlite]
#    ---------------------- ----------------- 28/50 [whenever]
#    ----------------------- ---------------- 29/50 [uvicorn]
#    ----------------------- ---------------- 29/50 [uvicorn]
#    ----------------------- ---------------- 29/50 [uvicorn]
#    ------------------------ --------------- 31/50 [starlette]
#    ------------------------ --------------- 31/50 [starlette]
#    ------------------------ --------------- 31/50 [starlette]
#    ------------------------- -------------- 32/50 [requests-oauthlib]
#    ------------------------- -------------- 32/50 [requests-oauthlib]
#    -------------------------- ------------- 33/50 [py-key-value-aio]
#    -------------------------- ------------- 33/50 [py-key-value-aio]
#    -------------------------- ------------- 33/50 [py-key-value-aio]
#    -------------------------- ------------- 33/50 [py-key-value-aio]
#    -------------------------- ------------- 33/50 [py-key-value-aio]
#    -------------------------- ------------- 33/50 [py-key-value-aio]
#    -------------------------- ------------- 33/50 [py-key-value-aio]
#    -------------------------- ------------- 33/50 [py-key-value-aio]
#    -------------------------- ------------- 33/50 [py-key-value-aio]
#    --------------------------- ------------ 34/50 [opentelemetry-api]
#    --------------------------- ------------ 34/50 [opentelemetry-api]
#    --------------------------- ------------ 34/50 [opentelemetry-api]
#    ---------------------------- ----------- 35/50 [jinja2-humanize-extension]
#    ---------------------------- ----------- 36/50 [h2]
#    ---------------------------- ----------- 36/50 [h2]
#    ------------------------------ --------- 38/50 [fakeredis]
#    ------------------------------ --------- 38/50 [fakeredis]
#    ------------------------------ --------- 38/50 [fakeredis]
#    ------------------------------ --------- 38/50 [fakeredis]
#    ------------------------------ --------- 38/50 [fakeredis]
#    ------------------------------ --------- 38/50 [fakeredis]
#    ------------------------------- -------- 39/50 [docker]
#    ------------------------------- -------- 39/50 [docker]
#    ------------------------------- -------- 39/50 [docker]
#    ------------------------------- -------- 39/50 [docker]
#    ------------------------------- -------- 39/50 [docker]
#    ------------------------------- -------- 39/50 [docker]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    -------------------------------- ------- 40/50 [dateparser]
#    --------------------------------- ------ 42/50 [griffe]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ---------------------------------- ----- 43/50 [apprise]
#    ----------------------------------- ---- 44/50 [alembic]
#    ----------------------------------- ---- 44/50 [alembic]
#    ----------------------------------- ---- 44/50 [alembic]
#    ----------------------------------- ---- 44/50 [alembic]
#    ----------------------------------- ---- 44/50 [alembic]
#    ----------------------------------- ---- 44/50 [alembic]
#    ----------------------------------- ---- 44/50 [alembic]
#    ------------------------------------ --- 45/50 [pydocket]
#    ------------------------------------ --- 45/50 [pydocket]
#    ------------------------------------ --- 45/50 [pydocket]
#    ------------------------------------ --- 46/50 [pydantic-extra-types]
#    ------------------------------------ --- 46/50 [pydantic-extra-types]
#    ------------------------------------- -- 47/50 [fastapi]
#    ------------------------------------- -- 47/50 [fastapi]
#    ------------------------------------- -- 47/50 [fastapi]
#    ------------------------------------- -- 47/50 [fastapi]
#    -------------------------------------- - 48/50 [cyclopts]
#    -------------------------------------- - 48/50 [cyclopts]
#    -------------------------------------- - 48/50 [cyclopts]
#    -------------------------------------- - 48/50 [cyclopts]
#    -------------------------------------- - 48/50 [cyclopts]
#    -------------------------------------- - 48/50 [cyclopts]
#    -------------------------------------- - 48/50 [cyclopts]
#    -------------------------------------- - 48/50 [cyclopts]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------  49/50 [prefect]
#    ---------------------------------------- 50/50 [prefect]
#
# Successfully installed Mako-1.3.10 aiosqlite-0.22.1 alembic-1.18.4 amplitude-analytics-1.2.2 annotated-doc-0.0.4 apprise-1.9.8 asgi-lifespan-2.1.0 asyncpg-0.31.0 beartype-0.22.9 cloudpickle-3.1.2 coolname-4.0.0 cronsim-2.7 cyclopts-4.10.0 dateparser-1.3.0 docker-7.1.0 docstring-parser-0.17.0 exceptiongroup-1.3.1 fakeredis-2.34.1 fastapi-0.135.1 graphviz-0.21 griffe-2.0.0 griffecli-2.0.0 griffelib-2.0.0 h2-4.3.0 hpack-4.1.0 humanize-4.15.0 hyperframe-6.1.0 jinja2-humanize-extension-0.4.0 lupa-2.6 oauthlib-3.3.1 opentelemetry-api-1.40.0 orjson-3.11.7 pluggy-1.6.0 prefect-3.6.22 py-key-value-aio-0.4.4 pydantic-extra-types-2.11.0 pydocket-0.18.2 pytz-2026.1.post1 redis-7.3.0 requests-oauthlib-2.0.0 rich-rst-1.3.2 semver-3.0.4 starlette-0.52.1 typing-extensions-4.15.0 typing-inspection-0.4.2 tzlocal-5.3.1 uncalled-for-0.2.0 uvicorn-0.41.0 websockets-16.0 whenever-0.9.5

# %% [markdown]
# In order to confirm the installation, run:

# %%
# !prefect version
# Out:
# Version:              3.6.22
# API version:          0.8.4
# Python version:       3.13.9
# Git commit:           6ee9deda
# Built:                Thu, Mar 12, 2026 08:44 PM
# OS/Arch:              win32/AMD64
# Profile:              ephemeral
# Server type:          ephemeral
# Pydantic version:     2.10.3
# Server:
#   Database:           sqlite
#   SQLite version:     3.51.1

# %% [markdown]
# ## Quickstar
# In this part we will develop a mini workflow. This for see how it works to specify the code it should run, where it should run and when it should run
#
# ### Install Prefect and start the server
# In this example we are running Prefect in Open Source, we need a server that backs the workflows. Let's start the local Server.

# %%
# !prefect server start

# %% [markdown]
# ## What code it should run
# We begin with a little program that fetches a list of customers ids and process them in prallel

# %%
from prefect import flow, task
import random 

@task
def get_customer_ids() -> list[str]:
    # Fetch customer IDs from a database or API
    return [f"Customer{n}" for n in random.choices(range(100), k=10)]

@task 
def process_customer(customer_id: str) -> str:
    # Process a single customer 
    return f"Processed {customer_id}"

@flow
def main() -> list[str]:
    customer_ids = get_customer_ids()
    # Map the process_customer task across all customer files
    results = process_customer.map(customer_ids)
    return results

if __name__ == "__main__":
    main()
# Out:
# 21:53:26.660 | INFO    | prefect - Starting temporary server on http://127.0.0.1:8585
# See https://docs.prefect.io/v3/concepts/server#how-to-guides for more information on running a dedicated Prefect server.
# 21:53:47.572 | INFO    | Flow run 'uber-hare' - Beginning flow run 'uber-hare' for flow 'main'
# 21:53:48.794 | INFO    | Task run 'get_customer_ids-d54' - Finished in state Completed()
# 21:53:48.865 | INFO    | Task run 'process_customer-10f' - Finished in state Completed()
# 21:53:48.881 | INFO    | Task run 'process_customer-537' - Finished in state Completed()
# 21:53:48.907 | INFO    | Task run 'process_customer-84a' - Finished in state Completed()
# 21:53:48.920 | INFO    | Task run 'process_customer-6d0' - Finished in state Completed()
# 21:53:48.923 | INFO    | Task run 'process_customer-ee9' - Finished in state Completed()
# 21:53:48.931 | INFO    | Task run 'process_customer-6e7' - Finished in state Completed()
# 21:53:48.947 | INFO    | Task run 'process_customer-e00' - Finished in state Completed()
# 21:53:48.953 | INFO    | Task run 'process_customer-167' - Finished in state Completed()
# 21:53:48.972 | INFO    | Task run 'process_customer-13e' - Finished in state Completed()
# 21:53:48.977 | INFO    | Task run 'process_customer-d68' - Finished in state Completed()
# 21:53:49.786 | INFO    | Flow run 'uber-hare' - Finished in state Completed('All states completed.')

# %% [markdown]
# For running this code locally, we must run the following command in a terminal

# %%
# git clone https://github.com/PrefectHQ/quickstart && cd quickstart
# python 01_getting_started.py

# %% [markdown]
# ## Where should it run?
# We already have run locally a main() file, we now use use serve() to update the file

# %%
from prefect import flow, task
import random

@task 
def get_customer_ids() -> list[str]:
    # Fetch customer IDs from a database or API
    return  [f"customer{n}" for n in random.choices(range(100),  k = 100)]

@task
def process_customer(customer_id: str) -> str:
    # Process a single customer
    return f"Processed {customer_id}"

@flow
def main() -> list[str]:
    customer_ids = get_customer_ids()
    # Map the process_customer task across all customer IDs
    results = process_customer.map(customer_ids)
    return results

if __name__ == "__main__":
    main.serve(name = "My-First-Deployment")
